# %%
from pyzbar import pyzbar
import argparse
import cv2
from matplotlib import pyplot as plt

# %%
# load the input image
image = cv2.imread('barcode.jpg')
# find the barcodes in the image and decode each of the barcodes
barcodes = pyzbar.decode(image)
plt.imshow(image)

# %%
# loop over the detected barcodes
for barcode in barcodes:
    (x, y, w, h) = barcode.rect
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)
    barcodeData = barcode.data.decode("utf-8")
    barcodeType = barcode.type
    text = "{} ({})".format(barcodeData, barcodeType)
    cv2.putText(image, text, (x, y - 20), cv2.FONT_HERSHEY_SIMPLEX,0.5, (0, 0, 255), 2)
    print("[INFO] Found {} barcode: {}".format(barcodeType, barcodeData))
plt.imshow(image)
plt.show()
# Out:
# [INFO] Found EAN13 barcode: 0012345678905

# %%
# load the input image
image = cv2.imread('barcode2.png')
# find the barcodes in the image and decode each of the barcodes
barcodes = pyzbar.decode(image)
plt.imshow(image)
# loop over the detected barcodes
for barcode in barcodes:
    (x, y, w, h) = barcode.rect
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)
    barcodeData = barcode.data.decode("utf-8")
    barcodeType = barcode.type
    text = "{} ({})".format(barcodeData, barcodeType)
    cv2.putText(image, text, (x, y - 20), cv2.FONT_HERSHEY_SIMPLEX,0.7, (255, 0, 0), 2)
    print("[INFO] Found {} barcode: {}".format(barcodeType, barcodeData))
plt.imshow(image)
plt.show()
# Out:
# [INFO] Found EAN13 barcode: 6004940002456
